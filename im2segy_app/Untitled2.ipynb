# %%
from PyQt5.QtGui import *
from PyQt5.QtCore import *
from PyQt5.QtWidgets import *
filename=r'D:\Ameyem\Bhugarbho\JOGMEC\SeismicSection\Vietnam\0045_1974_South China Sea_2D_Repro_1974_Time_Unmigrated_ A-103.tif'
image = QImage(filename)

# %%
from libs.combobox import ComboBox
from libs.default_label_combobox import DefaultLabelComboBox
from libs.resources import *
from libs.constants import *
from libs.utils import *
from libs.settings import Settings
from libs.shape import Shape, DEFAULT_LINE_COLOR, DEFAULT_FILL_COLOR
from libs.stringBundle import StringBundle
from libs.canvas import Canvas
from libs.zoomWidget import ZoomWidget
from libs.labelDialog import LabelDialog
from libs.colorDialog import ColorDialog
from libs.labelFile import LabelFile, LabelFileError, LabelFileFormat
from libs.toolBar import ToolBar
from libs.pascal_voc_io import PascalVocReader
from libs.pascal_voc_io import XML_EXT
from libs.yolo_io import YoloReader
from libs.yolo_io import TXT_EXT
from libs.create_ml_io import CreateMLReader
from libs.create_ml_io import JSON_EXT
from libs.ustr import ustr
from libs.hashableQListWidgetItem import HashableQListWidgetItem

# %%
folder_path=r'D:\Ameyem\Bhugarbho\JOGMEC\SeismicSection\Sarawak\rawimages'

# %%
from pathlib import Path
filename=r'D:\Ameyem\Bhugarbho\JOGMEC\SeismicSection\Sarawak\rawimages\0228_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-12A.tif'
# path=os.path(filename)
# os.walk(filename)
# path
path = Path(filename)
# print(Path(filename).absolute())
dir_path=Path(filename).parent.absolute()

# %%
import pandas as pd
trace_info=pd.read_excel(str(dir_path)+'/trace_info.xlsx',converters={'Fstr':str,'Traces':int})
trace_info['Fstr'].loc[0]
# Out:
# '0212'

# %%
# 
trace_info_indx=np.where(trace_info['Fstr']=='0228')[0][0]

# %%
import numpy as np
paths=['D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0212_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-01.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0213_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-02.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0214_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-03.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0215_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-04A.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0216_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-05.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0217_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-06.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0218_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-07.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0219_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-08.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0220_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-09.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0221_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-09A.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0222_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-10.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0223_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-10A.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0224_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-11W.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0225_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-11WA.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0226_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-11E.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0227_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-12.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0228_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-12A.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0229_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-13.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0230_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-14.tif', 
'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0286_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-55.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0287_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-56.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0288_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-57A.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0289_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-58.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0290_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-58.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0291_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-59.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0292_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-60.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0293_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-62.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0294_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-62B.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0295_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-63.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0296_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-64A.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0297_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-64.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0298_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-65.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0299_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-65A.tif', 'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0300_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-66.tif']
files=[f.split('\\')[-1] for f in paths]
files
fpath='D:\Ameyem\Bhugarbho\JOGMEC\SeismicSection\Sarawak\rawimages\\0228_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-12A.tif'
# fpath= r''+fpath
# file=fpath.split('\\')[-1]
file=fpath.split("\\")[-1]
# np.where(np.array(files)==file)
# os.path.abspath(fpath)
# fpath.split('\\x')
mfile_str=file[:4]
trace_info_indx=np.where(trace_info['Fstr']==mfile_str)[0][0]

trace_info['Traces'].iloc[trace_info_indx]
# Out:
# 1520

# %%
import os
def scan_all_images( folder_path):
    extensions = ['.tif']
    images = []

    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith(tuple(extensions)):
                relative_path = os.path.join(root, file)
                path = ustr(os.path.abspath(relative_path))
                images.append(path)
    natural_sort(images, key=lambda x: x.lower())
    return images
m_img_list=scan_all_images( folder_path)
m_img_list
# Out:
# ['D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0212_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-01.tif',
#  'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0213_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-02.tif',
#  'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0214_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-03.tif',
#  'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0215_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-04A.tif',
#  'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0216_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-05.tif',
#  'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0217_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-06.tif',
#  'D:\\Ameyem\\Bhugarbho\\JOGMEC\\SeismicSection\\Sarawak\\rawimages\\0218_1983_Block3_2D_Repro_1983_Time_UnMigrated_ 83-07.tif',
# ...

# %%
home = os.path.expanduser("~")
import pickle
data = {}
path = os.path.join(home, '.labelImgSettings.pkl')
path
if os.path.exists(path):
    with open(path, 'rb') as f:
        data = pickle.load(f)
#         return True
data
# Out:
# {'filename': '',
#  'window/size': PyQt5.QtCore.QSize(1916, 1006),
#  'window/position': PyQt5.QtCore.QPoint(0, 2),
#  'window/state': PyQt5.QtCore.QByteArray(b'\x00\x00\x00\xff\x00\x00\x00\x00\xfd\x00\x00\x00\x01\x00\x00\x00\x01\x00\x00\x01\x00\x00\x00\x03\x96\xfc\x02\x00\x00\x00\x02\xfb\x00\x00\x00\x0c\x00L\x00a\x00b\x00e\x00l\x00s\x01\x00\x00\x00D\x00\x00\x02[\x00\x00\x00\xfc\x00\xff\xff\xff\xfb\x00\x00\x00\n\x00F\x00i\x00l\x00e\x00s\x01\x00\x00\x02\xa3\x00\x00\x017\x00\x00\x00_\x00\xff\xff\xff\x00\x00\x06x\x00\x00\x03\x96\x00\x00\x00\x04\x00\x00\x00\x04\x00\x00\x00\x08\x00\x00\x00\x08\xfc\x00\x00\x00\x01\x00\x00\x00\x02\x00\x00\x00\x01\x00\x00\x00\x18\x00T\x00o\x00o\x00l\x00s\x00T\x00o\x00o\x00l\x00B\x00a\x00r\x01\x00\x00\x00\x00\xff\xff\xff\xff\x00\x00\x00\x00\x00\x00\x00\x00'),
#  'line/color': <PyQt5.QtGui.QColor at 0x25a94aff430>,
#  'fill/color': <PyQt5.QtGui.QColor at 0x25a94aff350>,
# ...

# %%
class CanvasMainWindow():
    FIT_WINDOW, FIT_WIDTH, MANUAL_ZOOM = list(range(3))

    def __init__(self, default_filename=None, default_prefdef_class_file=None, default_save_dir=None,parent=None):
        super(CanvasMainWindow, self).__init__(parent)
        self.parent=parent


        # Load setting in the main thread
        self.settings = Settings()
        self.settings.load()
        settings = self.settings

        self.os_name = platform.system()

        # Load string bundle for i18n
        self.string_bundle = StringBundle.get_bundle()
        get_str = lambda str_id: self.string_bundle.get_string(str_id)

        # Save as Pascal voc xml
        self.default_save_dir = default_save_dir
        self.label_file_format = settings.get(SETTING_LABEL_FILE_FORMAT, LabelFileFormat.PASCAL_VOC)

        # For loading all image under a directory
        self.m_img_list = []
        self.dir_name = None
        self.label_hist = []
        self.last_open_dir = None
        self.cur_img_idx = 0
        self.img_count = len(self.m_img_list)
def open_next_image(self, _value=False):
#     # Proceeding next image without dialog if having any label
#     if self.auto_saving.isChecked():
#         if self.default_save_dir is not None:
#             if self.dirty is True:
#                 self.save_file()
#         else:
#             self.change_save_dir_dialog()
#             return

    if not self.may_continue():
        return

    if self.img_count <= 0:
        return

    if not self.m_img_list:
        return

    filename = None
    if self.file_path is None:
        filename = self.m_img_list[0]
        self.cur_img_idx = 0
    else:
        if self.cur_img_idx + 1 < self.img_count:
            self.cur_img_idx += 1
            filename = self.m_img_list[self.cur_img_idx]

    if filename:
        self.load_file(filename)

# %%
from PIL.ImageQt import ImageQt
# ImageQt(image,QImage.Format_RGB888)

# %%
# # a,b=
# import numpy as np
# np.array(image.size())
# # a,b
dir(image)
image.width()
# Out:
# 55656

# %%
# import qimage2ndarray
# npimage = qimage2ndarray.recarray_view(image)
# npimage

# %%
dir(npimage)
npimage[0,0]
# Out:
# (254, 255, 255, 255)

# %%
# import opencv
import cv2
 
# Load the input image
image = cv2.imread(filename)
# cv2.imshow('Original', image)
# cv2.waitKey(0)
 
# Use the cvtColor() function to grayscale the image
# gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
gray_image.shape
import numpy as np
image = QImage.fromData(np.array(gray_image).astype(float))
image

# %%
# image_data = ImageQt(image)

# %%
# np.array(gray_image)
image = QImage(gray_image, gray_image.shape[1],\
                            gray_image.shape[0], gray_image.shape[1] * 3,QImage.Format_RGB888)
# Out:
# False

# %%
mimage=QImage(image,image.shape[0], image.shape[1] ,QImage.Format_RGB888)
mimage.isNull()
# Out:
# False

# %%
# dir(mimage)
import numpy as np
# mimage.toImageFormat
def QImageToCvMat(incomingImage):
    '''  Converts a QImage into an opencv MAT format  '''

    incomingImage = incomingImage.convertToFormat(QImage.Format.Format_RGBA8888)

    width = incomingImage.width()
    height = incomingImage.height()

    ptr = incomingImage.bits()
    ptr.setsize(height * width * 4)
    arr = np.frombuffer(ptr, np.uint8).reshape((height, width, 4))
    return arr
# def QImageToCvMat(incomingImage):
#     '''  Converts a QImage into an opencv MAT format  '''

#     incomingImage = incomingImage.convertToFormat(QImage.Format.Format_RGB32)

#     width = incomingImage.width()
#     height = incomingImage.height()

#     ptr = incomingImage.constBits()
#     arr = np.array(ptr).reshape(height, width, 4)  #  Copies the data
#     return arr

# %%
image

# %%
mmat=QImageToCvMat(image)
mmat

# %%
image = QImage(image, image.shape[1],\
                            image.shape[0], image.shape[1] ,QImage.Format_RGB888)
image.isNull()
# Out:
# True

# %%
# # ImageQt(gray_image)
# QImage.fromData(gray_image)
from libs.utils import *

# %%
# file_path=r'D:\Ameyem\Bhugarbho\JOGMEC\SeismicSection\Vietnam\0045_1974_South China Sea_2D_Repro_1974_Time_Unmigrated_ A-103.tif'

# # import os
# # file_path = ustr(file_path)

# # # Fix bug: An  index error after select a directory when open a new file.
# # unicode_file_path = ustr(file_path)
# # unicode_file_path = os.path.abspath(unicode_file_path)

# # if unicode_file_path and os.path.exists(unicode_file_path):

# im = cv2.imread('D:\Ameyem\Bhugarbho\JOGMEC\SeismicSection\Vietnam\0045_1974_South China Sea_2D_Repro_1974_Time_Unmigrated_ A-103.tif')

# %%
# dir(mimage)
import numpy as np
from seisimage_utils import *
import matplotlib.pyplot as plt
# import opencv
import cv2
filename=r'D:\Ameyem\Bhugarbho\JOGMEC\SeismicSection\Vietnam\rawimages\0048_1974_South China Sea_2D_Repro_1974_Time_Unmigrated_ A-109_crop.png'
# Load the input image
image = cv2.imread(filename)

# image = cv2.imread(filename)
oh,ow,_=image.shape
print(image.shape)
# if oh>4500:
#     fact=int(100*4500/oh)/100
#     image = cv2.resize(image, (0, 0), fx = fact, fy = fact)
# 

0.62

if oh>5000:
    fact=int(100*5000/oh)/100
    image = cv2.resize(image, (0, 0), fx = fact, fy = fact)
#     print('*************fact',fact)
#     prop_height=int(height*fact)
#     prop_width=int(image.width()*fact)
#     # print('prop_height,height,fact, height/fact ',prop_height,height,fact, height/fact)
#     pixmap = pixmap.scaledToHeight(prop_height)
image.shape
# Out:
# (4215, 29438, 3)
# (4215, 29438, 3)

# %%
clipped_im=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
zerotlineid
# Out:
# 7

# %%
zerotlineid=findHorlineIndex(clipped_im)
pad2blookedat=100
colnumbers,shifts2bapplied=getColumnShifts(clipped_im,zerotlineid,pad2blookedat)
plt.figure(figsize=(18,4))
plt.plot(shifts2bapplied)
clnidxs=getCleanedCurve(shifts2bapplied,returnsmooth=False)
plt.plot(clnidxs)
xlim=[6000,7000]
# plt.xlim(xlim)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2831bd2f1d77> in <module>
#       1 zerotlineid=findHorlineIndex(clipped_im)
#       2 pad2blookedat=100
# ----> 3 colnumbers,shifts2bapplied=getColumnShifts(clipped_im,zerotlineid,pad2blookedat)
#       4 plt.figure(figsize=(18,4))
#       5 plt.plot(shifts2bapplied)
#
# ~\OneDrive - ANTELOPUS ENERGY PRIVATE LIMITED\Python\Digitization\Image2Segy\im2segy_app\seisimage_utils.py in getColumnShifts(clipped_im, zerotlineid, pad2blookedat)
#     310     for i in range(window,opencvOutput.shape[1],window):
#     311         poo=opencvOutput[mp-ffpad:mp+fbpad,i-window:i]
# --> 312         idxs=np.argmin(poo,axis=0)
#     313         nowidxs=mp-ffpad+idxs
#     314         midxs.extend(list(nowidxs))
#
# <__array_function__ internals> in argmin(*args, **kwargs)
#
# ...

# %%
mp=zerotlineid
pad=int(clipped_im.shape[0]/30)
fpad,bpad=pad,pad
#     print(mp,pad)
if pad>mp:
    fpad=mp
resim=clipped_im[mp-fpad:mp+bpad,:]

horizontal = cv2.adaptiveThreshold(resim,255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,15,-2)
rows,cols = horizontal.shape
horizontalsize=10
#     print('horizontalsize',horizontalsize)
horizontalStructure = cv2.getStructuringElement(cv2.MORPH_RECT, (horizontalsize,1))
# horizontal = cv2.erode(horizontal, horizontalStructure, (-1, -1))
horizontal = cv2.dilate(horizontal, horizontalStructure, (-1, -1))

resim=horizontal.astype(float)
width=5
ncols=horizontalsize
mfilter=np.vstack([np.zeros((width,ncols))-0.5,np.ones((width,ncols)),np.zeros((width,ncols))-0.5])
opencvOutput = cv2.filter2D(resim, -1, mfilter)
ffpad=3 if fpad/2 >3 else int(fpad/2 )
fbpad=3
midxs=[]
window=10

# %%
# mp-ffpad,mp+fbpad
# midxs
# start,endx
mp
# Out:
# 7

# %%
for i in range(window,opencvOutput.shape[1],window):
    start,endx=mp-ffpad,mp+fbpad
    if start<0:
        start=0
    poo=opencvOutput[start:endx,i-window:i]    
#     print(i)
    idxs=np.argmin(poo,axis=0)
    nowidxs=start+idxs
    midxs.extend(list(nowidxs))
    mp=int(np.mean(nowidxs))
poo=opencvOutput[mp-ffpad:mp+fbpad,i:]    
idxs=np.argmin(poo,axis=0)
nowidxs=mp-ffpad+idxs
midxs.extend(list(nowidxs))
np.arange(len(midxs)), np.array(midxs)
# Out:
# (array([    0,     1,     2, ..., 29435, 29436, 29437]),
#  array([ 8,  7,  5, ..., 55, 55, 54], dtype=int64))

# %%
straightImage=getStraightenedImage(image,colnumbers,clnidxs)

# %%
plt.figure(figsize=(18,4))
plt.imshow(straightImage[:200,:])
xlim=[0,3000]
plt.xlim(xlim)  
plt.figure(figsize=(18,4))
plt.imshow(opencvOutput[:200,:])

plt.xlim(xlim) 

plt.figure(figsize=(18,4))
idxs=np.argmin(opencvOutput,axis=0)
plt.plot(np.array(midxs))
plt.xlim(xlim)
# Out:
# (0.0, 3000.0)

# %%
selim=clipped_im[:int(h/10),:int(w/55)]
plt.imshow(selim)
plt.show()
horizontal = cv2.adaptiveThreshold(selim,255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,15,-2)
rows,cols = horizontal.shape
horizontalsize = 20
horizontalStructure = cv2.getStructuringElement(cv2.MORPH_RECT, (horizontalsize,1))
# horizontal = cv2.erode(horizontal, horizontalStructure, (-1, -1))
horizontal = cv2.dilate(horizontal, horizontalStructure, (-1, -1))
# selim=horizontal.astype(float)
plt.imshow(horizontal)
plt.show()
selim=horizontal.astype(float)

# selim[selim<=127.0]=1
# selim[selim>127.0]=0
res=selim.sum(axis=1)
plt.plot(res)
# print(res.mean())
res[res<=res.mean()]=1
res[res>res.mean()]=0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6fe40a560688> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 selim=clipped_im[:int(h/10),:int(w/55)]
#       3 plt.imshow(selim)
#       4 plt.show()
#       5 horizontal = cv2.adaptiveThreshold(selim,255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,15,-2)
#
# NameError: name 'h' is not defined

# %%
xlim=[0,1000]
mp=zerotlineid
pad=int(clipped_im.shape[0]/30)
fpad,bpad=pad,pad
#     print(mp,pad)
if pad>mp:
    fpad=mp
resim=clipped_im[mp-fpad:mp+bpad,:]
plt.figure(figsize=(18,4))
plt.imshow(resim)
plt.xlim(xlim)

horizontal = cv2.adaptiveThreshold(resim,255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,15,-2)
rows,cols = horizontal.shape
#     print('rows,cols ',rows,cols )
#     horizontalsize = int(cols / 250)
horizontalsize=10
#     print('horizontalsize',horizontalsize)
horizontalStructure = cv2.getStructuringElement(cv2.MORPH_RECT, (horizontalsize,1))
horizontal = cv2.erode(horizontal, horizontalStructure, (-1, -1))
horizontal = cv2.dilate(horizontal, horizontalStructure, (-1, -1))

plt.figure(figsize=(18,4))
plt.imshow(horizontal)
plt.xlim(xlim)

resim=horizontal.astype(float)
width=5
ncols=horizontalsize
mfilter=np.vstack([np.zeros((width,ncols))-0.5,np.ones((width,ncols)),np.zeros((width,ncols))-0.5])
opencvOutput = cv2.filter2D(resim, -1, mfilter)
ffpad=3 if fpad/2 >3 else fpad/2 
fbpad=3
midxs=[]
mp=zerotlineid
window=10
for i in range(window,opencvOutput.shape[1],window):
    poo=opencvOutput[mp-ffpad:mp+fbpad,i-window:i]    
    idxs=np.argmin(poo,axis=0)
    nowidxs=mp-ffpad+idxs
    midxs.extend(list(nowidxs))
    mp=int(np.mean(nowidxs))
poo=opencvOutput[mp-ffpad:mp+fbpad,i:]    
idxs=np.argmin(poo,axis=0)
nowidxs=mp-ffpad+idxs
midxs.extend(list(nowidxs))
np.array(midxs)
    
plt.figure(figsize=(18,4))
plt.imshow(opencvOutput)
plt.xlim(xlim)  

plt.figure(figsize=(18,4))
idxs=np.argmin(opencvOutput,axis=0)
plt.plot(idxs)
# plt.ylim([0,200])

# %%
plt.figure(figsize=(18,4))
plt.plot(midxs)
clnidxs=getCleanedCurve(np.array(midxs),returnsmooth=True)
# shifts2bapplied=np.array(midxs)
# x=np.arange(len(shifts2bapplied))
# #     y=idxs
# z = np.polyfit(x, shifts2bapplied, 3)
# f = np.poly1d(z)
# mav = f(x)
# #     mav = savgol_filter(shifts2bapplied, 101, 3) # window size 51, polynomial order 3
# pttable=shifts2bapplied>=mav+1
# nttable=shifts2bapplied<=mav-1
# if sum(pttable)>0: shifts2bapplied[pttable]=mav[pttable]+1
# if sum(nttable)>0:shifts2bapplied[nttable]=mav[nttable]-1
    
plt.plot(clnidxs)
xlim=[6000,7000]
# plt.xlim(xlim)

# %%
def getCleanedCurve(shifts2bapplied,returnsmooth=False):
    # mav=movAverage(shifts2bapplied,5)
    x=np.arange(len(shifts2bapplied))
#     y=idxs
    z = np.polyfit(x, shifts2bapplied, 3)
    f = np.poly1d(z)
    mav = f(x)
#     mav = savgol_filter(shifts2bapplied, 101, 3) # window size 51, polynomial order 3
    pttable=shifts2bapplied>mav+1
    nttable=shifts2bapplied<mav-1
    if sum(pttable)>0: shifts2bapplied[pttable]=mav[pttable]+1
    if sum(nttable)>0:shifts2bapplied[nttable]=mav[nttable]-1
    if returnsmooth:
        return np.round(mav)
    return shifts2bapplied
def getColumnShifts(clipped_im,zerotlineid,pad2blookedat):
    mp=zerotlineid
    pad=int(clipped_im.shape[0]/30)
    fpad,bpad=pad,pad
    #     print(mp,pad)
    if pad>mp:
        fpad=mp
    resim=clipped_im[mp-fpad:mp+bpad,:]

    horizontal = cv2.adaptiveThreshold(resim,255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,15,-2)
    rows,cols = horizontal.shape
    horizontalsize=10
    #     print('horizontalsize',horizontalsize)
    horizontalStructure = cv2.getStructuringElement(cv2.MORPH_RECT, (horizontalsize,1))
    horizontal = cv2.erode(horizontal, horizontalStructure, (-1, -1))
    horizontal = cv2.dilate(horizontal, horizontalStructure, (-1, -1))

    resim=horizontal.astype(float)
    width=5
    ncols=horizontalsize
    mfilter=np.vstack([np.zeros((width,ncols))-0.5,np.ones((width,ncols)),np.zeros((width,ncols))-0.5])
    opencvOutput = cv2.filter2D(resim, -1, mfilter)
    ffpad=3 if fpad/2 >3 else fpad/2 
    fbpad=3
    midxs=[]
    mp=zerotlineid
    window=10
    for i in range(window,opencvOutput.shape[1],window):
        poo=opencvOutput[mp-ffpad:mp+fbpad,i-window:i]    
        idxs=np.argmin(poo,axis=0)
        nowidxs=mp-ffpad+idxs
        midxs.extend(list(nowidxs))
        mp=int(np.mean(nowidxs))
    poo=opencvOutput[mp-ffpad:mp+fbpad,i:]    
    idxs=np.argmin(poo,axis=0)
    nowidxs=mp-ffpad+idxs
    midxs.extend(list(nowidxs))
    return np.arange(len(midxs)), np.array(midxs)
