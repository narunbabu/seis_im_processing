# %%
import numpy as np
import PyQt5 #.QtCore as QtCore
projectfile=r'C:/Users/ArunBabu/OneDrive - ANTELOPUS ENERGY PRIVATE LIMITED/Python/Digitization/Image2Segy/MapDigitize/DigiProjects/secondproj.pd'
projectfile=r'C:\Users\ArunBabu\ANTELOPUS ENERGY PRIVATE LIMITED\GeoTech - Documents\6. Elao\1. Antelopus Analysis\Geophysics\map_degitization.pd'
projectfile=r'C:\Users\ArunBabu\ANTELOPUS ENERGY PRIVATE LIMITED\GeoTech - Documents\6. Elao\1. Antelopus Analysis\Geophysics/vspdigitize.pd'
projectfile=r'C:/Users/ArunBabu/OneDrive - ANTELOPUS ENERGY PRIVATE LIMITED/Python/Digitization/Image2Segy/MapDigitize/DigiProjects/latest.pd'
file = open(projectfile,'r')
text=file.read().split('\n')
print(text)
impath=text[0]
coordspath=text[1]
# Out:
# ['C:/Users/ArunBabu/OneDrive - ANTELOPUS ENERGY PRIVATE LIMITED/Python/Digitization/Image2Segy/MapDigitize/TERM-077-0020_00051279-1 Shot Poit Map.jpg', 'C:/Users/ArunBabu/OneDrive - ANTELOPUS ENERGY PRIVATE LIMITED/Python/Digitization/Image2Segy/MapDigitize/DigiProjects/latest/coordinates.npy', 'C:/Users/ArunBabu/OneDrive - ANTELOPUS ENERGY PRIVATE LIMITED/Python/Digitization/Image2Segy/MapDigitize/DigiProjects/latest/lines.npy', '']

# %%
# coordinates=[{'name': 'X1', 'pixel_loc': PyQt5.QtCore.QPointF(100.03606748109365, 85.52379290285049), 'value': 1993500.0}, 
#  {'name': 'X2', 'pixel_loc': PyQt5.QtCore.QPointF(944.7068062827224, 85.52379290285049), 'value': 1999500.0}, 
#  {'name': 'Y1', 'pixel_loc': PyQt5.QtCore.QPointF(77.49272833042465, 100.59965095986037), 'value': 1202500.0}, 
#  {'name': 'Y2', 'pixel_loc': PyQt5.QtCore.QPointF(77.49272833042465, 665.1694008144269), 'value': 1198500.0}]

# %%
# npfile='C:/Users/ArunBabu/ANTELOPUS ENERGY PRIVATE LIMITED/GeoTech - Documents/6. Elao/1. Antelopus Analysis/Geophysics/map_degitization/coordinates.npy'
# np.save(npfile,coordinates)
# [('', PyQt5.QtCore.QPointF(12504.529610238513, 2641.4538685282146)),
#   ('', PyQt5.QtCore.QPointF(13256.708318789997, 3319.4741128563123)),
#   ('', PyQt5.QtCore.QPointF(13899.415008726006, 4061.0587550901696))])
lines[l]
# ,mlines[l]
# Out:
# [('', PyQt5.QtCore.QPointF(831.1475409836066, 298.3606557377049)),
#  ('', PyQt5.QtCore.QPointF(1176.393442622951, 468.8524590163935))]

# %%
# text=r'C:\Users\ArunBabu\ANTELOPUS ENERGY PRIVATE LIMITED\GeoTech - Documents\6. Elao\1. Antelopus Analysis\Geophysics\locationmap.png'+'\n'
# text+=npfile
folder=r'C:/Users/ArunBabu/OneDrive - ANTELOPUS ENERGY PRIVATE LIMITED/Python/Digitization/Image2Segy/MapDigitize/DigiProjects//'
projectfile=folder+'latest.pd'
projectfile=folder+'PJ-038-1006_00051270-1.pd'
with open(projectfile,'r') as f:
    text=f.read()
    text=text.split('\n')
print(text)
coordsfile=text[1]
linesfile=text[2]

coords=np.load(coordsfile,allow_pickle=True)
rows=np.load(linesfile,allow_pickle=True)
lines=rows.item()
lines
mlines={}
for l in lines:
    print(lines[l])
    mlines[l]=[]
    for p in lines[l]:
        mlines[l].append(('',p))

np.save(linesfile,mlines)
# converter=CoordConverter(coords,lines)
# df=converter.getLineCoords()
# Out:
# ['D:/Ameyem/Bhugarbho/JOGMEC/ShotpointMap/Vietnam/PJ-038-1006_00051270-1_SP_Map_BlockVII_1.tif', 'C:/Users/ArunBabu/OneDrive - ANTELOPUS ENERGY PRIVATE LIMITED/Python/Digitization/Image2Segy/MapDigitize/DigiProjects/PJ-038-1006_00051270-1/coordinates.npy', 'C:/Users/ArunBabu/OneDrive - ANTELOPUS ENERGY PRIVATE LIMITED/Python/Digitization/Image2Segy/MapDigitize/DigiProjects/PJ-038-1006_00051270-1/lines.npy', '']
# [PyQt5.QtCore.QPointF(3495.9081967213115, 7714.111475409836), PyQt5.QtCore.QPointF(4882.714754098361, 6529.547540983606), PyQt5.QtCore.QPointF(6876.249180327869, 5056.065573770492), PyQt5.QtCore.QPointF(9187.59344262295, 3467.0163934426228), PyQt5.QtCore.QPointF(11152.23606557377, 2253.560655737705)]
# [PyQt5.QtCore.QPointF(4738.255737704918, 9418.727868852458), PyQt5.QtCore.QPointF(6009.495081967213, 8291.947540983607), PyQt5.QtCore.QPointF(7396.301639344262, 6991.816393442623), PyQt5.QtCore.QPointF(9274.268852459016, 5344.983606557377), PyQt5.QtCore.QPointF(11470.045901639343, 3611.4754098360654)]
# [PyQt5.QtCore.QPointF(8032.975308641975, 9883.135802469136), PyQt5.QtCore.QPointF(8723.858024691359, 9332.771604938273), PyQt5.QtCore.QPointF(9742.617283950618, 8302.302469135802), PyQt5.QtCore.QPointF(10655.987654320988, 7318.672839506173), PyQt5.QtCore.QPointF(11417.12962962963, 6545.820987654321), PyQt5.QtCore.QPointF(12178.271604938273, 6054.006172839506), PyQt5.QtCore.QPointF(12763.765432098766, 5503.641975308642)]
# [PyQt5.QtCore.QPointF(3243.635802469136, 5035.246913580247), PyQt5.QtCore.QPointF(4426.333333333333, 4145.2962962962965), PyQt5.QtCore.QPointF(7154.734567901234, 2798.6604938271603), PyQt5.QtCore.QPointF(9274.222222222223, 2037.5185185185185)]
# [PyQt5.QtCore.QPointF(2571.3704918032786, 7598.544262295082), PyQt5.QtCore.QPointF(4940.498360655738, 5749.4688524590165), PyQt5.QtCore.QPointF(7049.599999999999, 4247.095081967213), PyQt5.QtCore.QPointF(9563.186885245901, 2975.855737704918), PyQt5.QtCore.QPointF(11730.07213114754, 2166.8852459016393)]
# [PyQt5.QtCore.QPointF(1461.9811518324611, 9266.276672484004), PyQt5.QtCore.QPointF(4364.75532286213, 6314.0635253054115)]
# [PyQt5.QtCore.QPointF(2298.912390924957, 9923.10878417685), PyQt5.QtCore.QPointF(6787.265154159397, 5335.878068644562)]
# [PyQt5.QtCore.QPointF(3782.1602415803623, 9914.66291899995), PyQt5.QtCore.QPointF(9459.556823996598, 4060.6269846417736)]
# [PyQt5.QtCore.QPointF(6564.749562171629, 10037.271410347885), PyQt5.QtCore.QPointF(12410.473056438419, 3967.112033613688)]
# [PyQt5.QtCore.QPointF(7524.836392726644, 9769.195217400706), PyQt5.QtCore.QPointF(12564.25319812905, 4553.139060056359), PyQt5.QtCore.QPointF(12718.03333981968, 4403.5151384114215), PyQt5.QtCore.QPointF(13214.701635279958, 4002.4399040020758), PyQt5.QtCore.QPointF(13285.357376056734, 3925.5498331567605), PyQt5.QtCore.QPointF(13900.477942819254, 2915.5883620534332)]
# [PyQt5.QtCore.QPointF(8067.223108689542, 9935.444019228413), PyQt5.QtCore.QPointF(13524.340028684064, 4337.015617680338), PyQt5.QtCore.QPointF(13896.321722773562, 3948.4090434080704)]
# [PyQt5.QtCore.QPointF(8790.405396640073, 9931.28779918272), PyQt5.QtCore.QPointF(13881.774952613638, 4723.54408192976), PyQt5.QtCore.QPointF(13987.758563778802, 4623.794800833135)]
# [PyQt5.QtCore.QPointF(9509.43146454491, 9937.52212925126), PyQt5.QtCore.QPointF(12865.57915144177, 6458.765951006465)]
# [PyQt5.QtCore.QPointF(10130.786361375971, 10016.490310119421), PyQt5.QtCore.QPointF(13096.249363977717, 7032.324317312058)]
# [PyQt5.QtCore.QPointF(10862.281089417887, 9904.272368885719), PyQt5.QtCore.QPointF(13935.805813207642, 6826.591425050269)]
# [PyQt5.QtCore.QPointF(11681.05643841935, 9945.834569342645), PyQt5.QtCore.QPointF(13898.39983279641, 7711.866294782816)]
# [PyQt5.QtCore.QPointF(12404.23872636988, 9958.303229479723), PyQt5.QtCore.QPointF(13937.883923230489, 8408.033152436345)]
# [PyQt5.QtCore.QPointF(13104.561804069102, 9939.600239274107), PyQt5.QtCore.QPointF(13931.64959316195, 9081.340799838563)]
# [PyQt5.QtCore.QPointF(1903.5487809272593, 8021.504688186922), PyQt5.QtCore.QPointF(3742.6761511462814, 9906.350478908564)]
# [PyQt5.QtCore.QPointF(2524.9036777583187, 7163.245248751378), PyQt5.QtCore.QPointF(5274.243237984044, 10006.099760005189)]
# [PyQt5.QtCore.QPointF(3445.506417879253, 6635.405302948405), PyQt5.QtCore.QPointF(6649.952073108329, 9937.52212925126)]
# [PyQt5.QtCore.QPointF(4623.794800833135, 6307.063919338681), PyQt5.QtCore.QPointF(8154.503729649089, 10020.646530165113)]
# [PyQt5.QtCore.QPointF(7614.195123709037, 8707.280995726218), PyQt5.QtCore.QPointF(8807.030276822843, 9927.131579137027)]
# [PyQt5.QtCore.QPointF(5527.772660771298, 5833.254834129712), PyQt5.QtCore.QPointF(9619.571295755768, 10049.740070484962)]
# [PyQt5.QtCore.QPointF(7724.334954919894, 7325.3378305333945), PyQt5.QtCore.QPointF(10371.847124026148, 10064.286840644887)]
# [PyQt5.QtCore.QPointF(6442.1410708236945, 5295.024338212507), PyQt5.QtCore.QPointF(10978.655250697282, 9937.52212925126)]
# [PyQt5.QtCore.QPointF(7574.757417102968, 4958.023036649216), PyQt5.QtCore.QPointF(12522.186387434558, 10039.64351367074)]
# [PyQt5.QtCore.QPointF(8432.876788830717, 4385.943455497383), PyQt5.QtCore.QPointF(9481.689354275744, 5441.818731820827), PyQt5.QtCore.QPointF(9707.696102385109, 5660.762769051776), PyQt5.QtCore.QPointF(10389.247702152416, 6504.756719022689), PyQt5.QtCore.QPointF(10474.000232693428, 6582.4465386852835), PyQt5.QtCore.QPointF(10887.168819080864, 6914.393949970915), PyQt5.QtCore.QPointF(13857.0387434555, 9940.765561372893)]
# [PyQt5.QtCore.QPointF(9965.485049447356, 4488.352763234439), PyQt5.QtCore.QPointF(10940.139150668996, 5494.78906340896), PyQt5.QtCore.QPointF(11554.594997091335, 6112.776265270508), PyQt5.QtCore.QPointF(13888.82094240838, 8521.160674810939)]
# [PyQt5.QtCore.QPointF(10604.660383944156, 3637.2961023851085), PyQt5.QtCore.QPointF(11445.12297847586, 4502.478184991275), PyQt5.QtCore.QPointF(12282.054217568357, 5371.1916230366505), PyQt5.QtCore.QPointF(13941.791273996512, 7083.899011052939)]
# [PyQt5.QtCore.QPointF(10911.888307155325, 3241.784293193718), PyQt5.QtCore.QPointF(11946.575450843517, 4283.534147760327), PyQt5.QtCore.QPointF(13899.415008726006, 6324.657591623038)]
# [PyQt5.QtCore.QPointF(11575.783129726588, 3192.3453170447942), PyQt5.QtCore.QPointF(12352.681326352533, 3972.7748691099487), PyQt5.QtCore.QPointF(13853.50738801629, 5519.508551483422)]
# [PyQt5.QtCore.QPointF(12101.955090168705, 2973.401279813846), PyQt5.QtCore.QPointF(13895.883653286797, 4724.953577661432)]
# [PyQt5.QtCore.QPointF(12504.529610238513, 2641.4538685282146), PyQt5.QtCore.QPointF(13256.708318789997, 3319.4741128563123), PyQt5.QtCore.QPointF(13899.415008726006, 4061.0587550901696)]

# %%
# file='C:/Users/ArunBabu/OneDrive - ANTELOPUS ENERGY PRIVATE LIMITED/Python/Digitization/Image2Segy/MapDigitize/DigiProjects/PJ-038-1006_00051270-1/coordinates.npy'
# Out:
# (array([[ 97.36019111,  85.03436322],
#         [738.1647491 ,  97.9141609 ],
#         [ 97.49868356,  85.44984056],
#         [ 84.61888587, 721.54565531]]),
#  [0.0, 1500.0, 0.0, 1500.0])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# # twopoints[:,1],twovals,yperpixunit
# midy=np.argmin(twopoints[:,1])
# twopoints[idy,1]

# %%
# plt.plot(locations[:2,0],locations[:2,1])
twovals=values[:2]
twopoints=locations[:2,:]
x,y,xd,yd=getXdYd(twopoints,twovals)
# print(xd,yd)
# distance=twovals[1]-twovals[0]
# y=twopoints[1,1]-twopoints[0,1]
# x=twopoints[1,0]-twopoints[0,0]
# theta=np.arctan(y/x)

# theta,np.tan(theta),y/x
# xd=distance*np.cos(theta)
# yd=distance*np.sin(theta)
print(xd,yd)
plt.plot(locations[2:,0],locations[2:,1])

minidx=np.argmin(twopoints[:,0])
minval=twovals[minidx]
minx=twopoints[minidx,0]
minval,minx

# y,x,distance
# twopoints[1,1],twopoints[0,1]
# xd/x
xperpixunit=xd/x
# yperpixunit=yd/y
# xperpixunit,yperpixunit

# x*xperpixunit

xval_at_orgin=minval-minx*xperpixunit
xval_at_orgin,xperpixunit
# Out:
# 1499.6971018652064 30.143036627072448
# (-227.85542740679492, 2.340334635834626)

# %%
plt.plot(locations[2:,0],locations[2:,1])

# %%
# plt.plot(locations[:2,0],locations[:2,1])
import pandas as pd
class CoordConverter:
    def __init__(self,coords,lines):
        super().__init__()
        self.coords=coords
        self.lines=lines
    def getOriginsValperUnit(self,locations,values):

        def getXdYd(twopoints,twovals):
            distance=twovals[1]-twovals[0]
            y=twopoints[1,1]-twopoints[0,1]
            x=twopoints[1,0]-twopoints[0,0]
            theta=np.arctan(y/x)
            # print(x,y,theta)
            theta,np.tan(theta),y/x
            xd=distance*np.cos(theta)
            yd=distance*np.sin(theta)
            return x,y,xd,yd

        #X-axis
        twovals=values[:2]
        twopoints=locations[:2,:]
        x,y,xd,yd=getXdYd(twopoints,twovals)

        minidx=np.argmin(twopoints[:,0])
        minval=twovals[minidx]
        minx=twopoints[minidx,0]
        xperpixunit=xd/x
        xval_at_orgin=minval-minx*xperpixunit

        #Y-axis
        twovals=values[2:]
        twopoints=locations[2:,:]
        x,y,xd,yd=getXdYd(twopoints,twovals)
        # print(xd,yd)

        midy=np.argmin(twopoints[:,1])
        minval=twovals[midy]
        miny=twopoints[midy,1]
        yperpixunit=yd/y
        yval_at_orgin=minval-miny*yperpixunit

        return xval_at_orgin,xperpixunit,yval_at_orgin,yperpixunit
    def processCoordinates(self):
    #     rows=np.load(coordsfile,allow_pickle=True)
    #     rows
        locations=[]
        values=[]
        for row in self.coords:
        #     print(row['name'],row['pixel_loc'],row['value'])
            locations.append([row['pixel_loc'].x(),row['pixel_loc'].y()])
            values.append(row['value'])
        locations=np.array(locations)
        xval_at_orgin,xperpixunit,yval_at_orgin,yperpixunit = self.getOriginsValperUnit(locations,values)
        return xval_at_orgin,xperpixunit,yval_at_orgin,yperpixunit
    def getLineCoords(self):
        lno=[]
        xs=[]
        ys=[]
        attr=[]
        for key in self.lines:
            if len(self.lines[key])>0:
                for a,l in self.lines[key]:
                    xs.append(l.x())
                    ys.append(l.y())
                    lno.append(key)
                    attr.append(a)
        df=pd.DataFrame({'lno':lno,'shotpoint':attr,'X':xs,'Y':ys})
        df['X-Coord']=xval_at_orgin+df.X*xperpixunit
        df['Y-Coord']=yval_at_orgin+df.Y*yperpixunit
        return df

# %%
# print(xd,yd)
# plt.plot(locations[2:,0],locations[2:,1])
coords=np.load(coordsfile,allow_pickle=True)
rows=np.load(linesfile,allow_pickle=True)
lines=rows.item()
converter=CoordConverter(coords,lines)
df=converter.getLineCoords()
# processCoordinates(coords)
df
# Out:
#         lno shotpoint            X            Y      X-Coord      Y-Coord
# 0   l111111         1   622.295082   434.754098  1228.523307  -823.537900
# 1   l111111         2   963.278689   515.737705  2026.539051 -1014.469066
# 2   l111111            1278.688525   575.409836  2764.703615 -1155.155188
# 3   l222222         6   490.163934   895.081967   919.292206 -1908.830844
# 4   l222222         7   899.344262  1022.950820  1876.911099 -2210.301106
# 5   l222222            1632.459016  1193.442623  3592.644950 -2612.261456
# 6   l222222            1575.891678   866.413474  3460.258448 -1841.240513
# 7   l222222            1575.891678   866.413474  3460.258448 -1841.240513
# 8   l222222            1765.521797  1039.696169  3904.056383 -2249.780813
# 9   l222222            1765.521797  1039.696169  3904.056383 -2249.780813
# 10    l3333        33   493.692206   637.549538   927.549542 -1301.658983
# 11    l3333        34   493.692206   637.549538   927.549542 -1301.658983
# 12    l3333        35   889.299868   817.371202  1853.403855 -1725.615899
# 13    l3333             889.299868   817.371202  1853.403855 -1725.615899
# 14    l3333            1209.709379  1029.887715  2603.269332 -2226.655891
# 15    l3333            1209.709379  1029.887715  2603.269332 -2226.655891
# 16    l3333            1651.089828  1278.368560  3636.247285 -2812.487266
# 17    l3333            1651.089828  1278.368560  3636.247285 -2812.487266
# 18     l444             605.245902  1142.295082  1188.622519 -2491.673351
# 19     l444             605.245902  1142.295082  1188.622519 -2491.673351
# 20     l444             814.098361  1282.950820  1677.407163 -2823.290639
# 21     l444             814.098361  1282.950820  1677.407163 -2823.290639
# 22    l5555            1380.983607   392.131148  3004.108339  -723.047812
# 23    l5555            1380.983607   392.131148  3004.108339  -723.047812
# 24    l5555            1704.918033   558.360656  3762.223296 -1114.959153
# 25    l5555            1704.918033   558.360656  3762.223296 -1114.959153
# 26    l5555            2003.278689   737.377049  4460.487073 -1537.017520
# 27    l5555            2003.278689   737.377049  4460.487073 -1537.017520
# 28     l666             421.967213  1564.262295   759.689057 -3486.525216
# 29     l666             669.180328  1756.065574  1338.250472 -3938.730610
# 30     l666             886.557377  1922.295082  1846.985509 -4330.641951
# 31     l777            1133.770492  1167.868852  2425.546924 -2551.967403
# 32     l777            1133.770492  1167.868852  2425.546924 -2551.967403
# 33     l777            1312.786885  1483.278689  2844.505190 -3295.594050
# 34     l777            1312.786885  1483.278689  2844.505190 -3295.594050
# 35     l888            1410.819672   230.163934  3073.934716  -341.185480
# 36     l888            1410.819672   230.163934  3073.934716  -341.185480
# 37     l888            1704.918033   200.327869  3762.223296  -270.842419
# 38     l888            1704.918033   200.327869  3762.223296  -270.842419
# 39     l999             831.147541   298.360656  1717.307950  -501.969620
# 40     l999            1176.393443   468.852459  2525.298892  -903.929970

# %%
# file=r'C:\Users\ArunBabu\OneDrive - ANTELOPUS ENERGY PRIVATE LIMITED\Python\Digitization\Image2Segy\MapDigitize\DigiProjects\PJ-038-1006_00051270-1/lines.npy'

# %%
yval_at_orgin,yperpixunit,xval_at_orgin,xperpixunit
# Out:
# (201.46099184813286,
#  -2.357652050879685,
#  -227.85542740679492,
#  2.340334635834626)

# %%
# dir(rows.item)
# rows.get('75-701')
lno=[]
xs=[]
ys=[]
for key in lines:
#     if '74-' in key:
        print(key,'.........')
        if len(lines[key])>0:
            for l in lines[key]:
                xs.append(l.x())
                ys.append(l.y())
                lno.append(key)
#                 print('  ',l.x(),l.y())
len(lno)
# Out:
# None .........
# checkshot .........
# checkshot2 .........
# 44

# %%
import pandas as pd
df=pd.DataFrame({'lno':lno,'X':xs,'Y':ys})
df['X-Coord']=xval_at_orgin+df.X*xperpixunit
df['Y-Coord']=yval_at_orgin+df.Y*yperpixunit
df
# Out:
#            lno           X           Y      X-Coord      Y-Coord
# 0         None  104.284814  695.924552    16.205934 -1439.286956
# 1    checkshot  228.870877  187.796728   307.779012  -241.298350
# 2    checkshot  240.723119  200.875064   335.517225  -272.132515
# 3    checkshot  253.392756  213.953400   365.168417  -302.966680
# 4    checkshot  271.171119  235.205696   406.775735  -353.072199
# 5    checkshot  284.658153  249.918823   438.339907  -387.760635
# 6    checkshot  297.532140  264.018904   468.469344  -421.003719
# 7    checkshot  322.667066  293.445160   527.293484  -490.380591
# 8    checkshot  341.671523  314.901804   571.770272  -540.967893
# 9    checkshot  353.115067  328.184489   598.551994  -572.283842
# 10   checkshot  383.563067  362.923819   669.810504  -654.187094
# 11   checkshot  417.893699  401.137081   750.155670  -744.280670
# 12   checkshot  431.380733  415.237162   781.719843  -777.523755
# 13   checkshot  441.802532  424.024169   806.110340  -798.240460
# 14   checkshot  458.967847  439.759042   846.282923  -835.337815
# 15   checkshot  460.602639  448.341700   850.108883  -855.572736
# 16   checkshot  469.798344  460.398290   871.629909  -883.997982
# 17   checkshot  484.715821  475.520116   906.541797  -919.649985
# 18   checkshot  493.707177  486.350613   927.584579  -945.184528
# 19   checkshot  505.559419  500.450694   955.322791  -978.427613
# 20   checkshot  520.885593  517.616010   991.191168 -1018.897455
# 21  checkshot2  536.007419  534.781325  1026.581301 -1059.367296
# 22  checkshot2  552.559688  553.172735  1065.319149 -1102.727841
# 23  checkshot2  566.659769  569.929353  1098.318056 -1142.234116
# 24  checkshot2  585.255528  590.364252  1141.838355 -1190.412499
# 25  checkshot2  595.268628  603.238239  1165.272361 -1220.764880
# 26  checkshot2  606.712172  619.586159  1192.054083 -1259.307587
# 27  checkshot2  617.338320  634.094938  1216.922825 -1293.514239
# 28  checkshot2  628.986213  650.851556  1244.182792 -1333.020513
# 29  checkshot2  640.838455  665.769032  1271.921004 -1368.190733
# 30  checkshot2  654.121140  680.890858  1303.006932 -1403.842736
# 31  checkshot2  661.682052  697.238778  1320.701998 -1442.385443
# 32  checkshot2  673.125596  712.769302  1347.483720 -1479.001014
# 33  checkshot2  686.203932  727.482429  1378.091402 -1513.689450
# 34  checkshot2  698.464872  741.991208  1406.786104 -1547.896102
# 35  checkshot2  713.178000  762.426108  1441.219747 -1596.074485
# 36  checkshot2  724.825893  780.613169  1468.479714 -1638.953246
# 37  checkshot2  734.430295  795.530646  1490.957231 -1674.123466
# 38  checkshot2  744.034698  813.104659  1513.434747 -1715.556876
# 39  checkshot2  751.391262  829.656928  1530.651568 -1754.581366
# 40  checkshot2  756.704336  840.896123  1543.085939 -1781.079477
# 41  checkshot2  757.521732  856.017949  1544.998920 -1816.731480
# 42  checkshot2  757.726081  870.731076  1545.477165 -1851.419916
# 43  checkshot2  758.747826  884.422459  1547.868390 -1883.699433

# %%
import pandas as pd

# %%
xlsfile=r'C:\Users\ArunBabu\OneDrive - ANTELOPUS ENERGY PRIVATE LIMITED\Python\Digitization\Image2Segy\MapDigitize\DigiProjects\PJ-038-1006_00051270-1/PJ-038-1006_00051270-1.xlsx'
# df[['lno','X-Coord','Y-Coord']].to_excel(xlsfile)
df.to_excel(linesfile.replace('.npy','.xlsx'))

# %%
plt.plot(df['X-Coord'],df['Y-Coord'],'*')
